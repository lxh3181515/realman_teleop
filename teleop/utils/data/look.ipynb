# %%
import numpy as np
import os

# 假设 args.task_dir 是已知的目录路径
task_dir = "./"  # 替换为实际路径
head_record_path = os.path.join(task_dir, 'head_record.npy')

# 读取文件
head_record = np.load(head_record_path)

# 打印内容
print(head_record)
# Out:
# [[ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
#  [ 0.2  0.   1.5  0.  -0.   0. ]
# ...

# %%
head_record.shape
# Out:
# (123, 6)
